# %%
# !pip install mysql.connector
# Out:
# ...
#   Using cached mysql_connector-2.2.9-cp312-cp312-win_amd64.whl
# ...

# %%
import mysql.connector

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
db = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "Musalaiah@7114",
    database = "coffe",
    auth_plugin = 'mysql_native_password',
    use_pure=True
)


mycursor = db.cursor()

print(db)

# %%
mycursor.execute("Select * from products")

output = mycursor.fetchall()

for x in output:
    print(x)
# Out:
# (1, 'COF0001', 'Macchiato', Decimal('317.45'), 186, 'Mint', 'Cold', 'Medium', 332, 'Spices, Sugar', 1, Decimal('3.0'))
# (2, 'COF0002', 'Frappuccino', Decimal('60.35'), 172, 'Hazelnut', 'Iced', 'Large', 483, 'Chocolate, Spices, Coffee Beans, Sugar, Tea Leaves', 0, Decimal('3.5'))
# (3, 'COF0003', 'Iced Latte', Decimal('216.77'), 26, 'Cinnamon', 'Iced', 'Small', 485, 'Ice, Sugar, Chocolate, Milk, Tea Leaves', 1, Decimal('3.5'))
# (4, 'COF0004', 'Latte', Decimal('289.52'), 21, 'None', 'Hot', 'Small', 418, 'Milk, Tea Leaves', 0, Decimal('3.7'))
# (5, 'COF0005', 'Latte', Decimal('171.15'), 84, 'None', 'Iced', 'Small', 336, 'Coffee Beans, Tea Leaves, Ice, Milk, Chocolate', 0, Decimal('2.3'))
# (6, 'COF0006', 'Frappuccino', Decimal('378.72'), 158, 'Cinnamon', 'Iced', 'Medium', 221, 'Spices, Coffee Beans', 1, Decimal('4.7'))
# (7, 'COF0007', 'Mocha', Decimal('491.30'), 116, 'Hazelnut', 'Iced', 'Medium', 120, 'Ice, Cream', 0, Decimal('2.5'))
# ...

# %%
query = "select * from products"

data = pd.read_sql(query,db)
data
# Out:
#         id product_id product_name   price  quantity   flavors category  \
# 0        1    COF0001    Macchiato  317.45       186      Mint     Cold
# 1        2    COF0002  Frappuccino   60.35       172  Hazelnut     Iced
# 2        3    COF0003   Iced Latte  216.77        26  Cinnamon     Iced
# 3        4    COF0004        Latte  289.52        21      None      Hot
# 4        5    COF0005        Latte  171.15        84      None     Iced
# ...    ...        ...          ...     ...       ...       ...      ...
# 1995  1996    COF1996   Cappuccino  347.71        87      None      Hot
# 1996  1997    COF1997  Masala Chai  378.81        61      Mint     Cold
# 1997  1998    COF1998   Cappuccino  414.92        82  Hazelnut     Cold
# 1998  1999    COF1999    Americano  455.15        23  Hazelnut     Cold
# 1999  2000    COF2000   Iced Latte   50.43        86   Caramel      Hot
#
#         size  calories                                        ingredients  \
# ...

# %%
data.shape
# Out:
# (2000, 12)

# %%
data.shape[0]
# Out:
# 2000

# %%
data.shape[1]
# Out:
# 12

# %%
data.tail()
# Out:
#         id product_id product_name   price  quantity   flavors category  \
# 1995  1996    COF1996   Cappuccino  347.71        87      None      Hot
# 1996  1997    COF1997  Masala Chai  378.81        61      Mint     Cold
# 1997  1998    COF1998   Cappuccino  414.92        82  Hazelnut     Cold
# 1998  1999    COF1999    Americano  455.15        23  Hazelnut     Cold
# 1999  2000    COF2000   Iced Latte   50.43        86   Caramel      Hot
#
#         size  calories                                  ingredients  \
# 1995   Large       491                            Chocolate, Spices
# 1996  Medium       407       Milk, Cream, Spices, Coffee Beans, Ice
# 1997   Large       109          Chocolate, Spices, Milk, Tea Leaves
# 1998   Large       132               Chocolate, Coffee Beans, Sugar
# 1999  Medium       128  Chocolate, Tea Leaves, Coffee Beans, Spices
#
#       availability  rating
# 1995             1     1.9
# 1996             1     4.6
# 1997             1     4.0
# ...

# %%
data.describe()
# Out:
#                 id        price    quantity    calories  availability  \
# count  2000.000000  2000.000000  2000.00000  2000.00000   2000.000000
# mean   1000.500000   277.310190   105.03800   300.78450      0.510500
# std     577.494589   128.978746    55.35965   117.27695      0.500015
# min       1.000000    50.430000    10.00000   100.00000      0.000000
# 25%     500.750000   165.990000    57.00000   196.00000      0.000000
# 50%    1000.500000   275.065000   106.00000   306.00000      1.000000
# 75%    1500.250000   386.517500   153.00000   402.00000      1.000000
# max    2000.000000   499.880000   200.00000   500.00000      1.000000
#
#             rating
# count  2000.000000
# mean      3.016350
# std       1.145554
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       5.000000

# %%
data.nlargest(5,'price')
# Out:
#         id product_id  product_name   price  quantity   flavors category  \
# 836    837    COF0837   Masala Chai  499.88        51      Mint      Hot
# 161    162    COF0162         Latte  499.76        93  Cardamom      Hot
# 1269  1270    COF1270         Latte  499.68       123   Caramel  Blended
# 1084  1085    COF1085  Choco Frappe  499.57        29  Cardamom     Cold
# 1235  1236    COF1236   Masala Chai  499.32       187  Cardamom      Hot
#
#         size  calories                             ingredients  availability  \
# 836   Medium       144  Coffee Beans, Milk, Sugar, Ice, Spices             1
# 161    Large       461         Chocolate, Coffee Beans, Spices             1
# 1269   Small       164            Ice, Chocolate, Coffee Beans             1
# 1084   Small       197        Coffee Beans, Milk, Cream, Sugar             1
# 1235   Small       489               Spices, Ice, Coffee Beans             0
#
#       rating
# 836      4.4
# 161      1.7
# 1269     2.1
# ...

# %%
data[['product_name','flavors']].value_counts()
# Out:
# product_name  flavors
# Masala Chai   Cardamom     37
# Espresso      Vanilla      35
# Iced Latte    Cinnamon     35
# Latte         None         33
# Macchiato     Caramel      33
#                            ..
# Cappuccino    Mint         16
# Latte         Hazelnut     16
# Espresso      Chocolate    16
# Masala Chai   Hazelnut     16
# Cappuccino    Cinnamon     13
# Name: count, Length: 80, dtype: int64

# %%
data['product_name'].head()
# Out:
# 0      Macchiato
# 1    Frappuccino
# 2     Iced Latte
# 3          Latte
# 4          Latte
# Name: product_name, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\Appointment Scheduling Cleaned Data.csv")

# %%
data
# Out:
#       Requesting date   Appointment date Client ID Provider Role First Name  \
# 0    9/20/23 12:18 PM   9/21/23 12:45 PM         1         Nurse      Aayan
# 1    9/20/23 12:19 PM   9/29/23 10:47 AM         2         Nurse     Minnie
# 2     9/20/23 2:56 PM  10/23/23 11:50 AM         3         Nurse     Bianca
# 3     9/20/23 2:56 PM   10/16/23 3:04 PM         4         Nurse   Rosalind
# 4     9/20/23 2:56 PM   10/16/23 3:04 PM         5         Nurse      Zaara
# ..                ...                ...       ...           ...        ...
# 94  10/18/23 10:03 PM   10/30/23 9:31 PM        95            MD     Samson
# 95   10/31/23 6:46 PM    11/7/23 2:39 PM        96            MD   Ibraheem
# 96   10/19/23 8:48 AM  10/23/23 10:02 AM        97            MD   Cordelia
# 97   10/27/23 1:08 PM  10/30/23 10:45 AM        98            MD     Oliwia
# 98   10/27/23 1:09 PM  10/30/23 10:14 AM        99            MD      Aidan
#
#    Last Name         Full Name       Waiting Time
# ...

# %%
data.head()
# Out:
#     Requesting date   Appointment date Client ID Provider Role First Name  \
# 0  9/20/23 12:18 PM   9/21/23 12:45 PM         1         Nurse      Aayan
# 1  9/20/23 12:19 PM   9/29/23 10:47 AM         2         Nurse     Minnie
# 2   9/20/23 2:56 PM  10/23/23 11:50 AM         3         Nurse     Bianca
# 3   9/20/23 2:56 PM   10/16/23 3:04 PM         4         Nurse   Rosalind
# 4   9/20/23 2:56 PM   10/16/23 3:04 PM         5         Nurse      Zaara
#
#   Last Name       Full Name       Waiting Time
# 0   Johnson   Aayan Johnson   31 days, 0 hours
# 1     Pratt    Minnie Pratt   7 days, 22 hours
# 2   English  Bianca English  31 days, 20 hours
# 3      Love   Rosalind Love   25 days, 0 hours
# 4     Lynch     Zaara Lynch   25 days, 0 hours

# %%
data.tail()
# Out:
#       Requesting date   Appointment date Client ID Provider Role First Name  \
# 94  10/18/23 10:03 PM   10/30/23 9:31 PM        95            MD     Samson
# 95   10/31/23 6:46 PM    11/7/23 2:39 PM        96            MD   Ibraheem
# 96   10/19/23 8:48 AM  10/23/23 10:02 AM        97            MD   Cordelia
# 97   10/27/23 1:08 PM  10/30/23 10:45 AM        98            MD     Oliwia
# 98   10/27/23 1:09 PM  10/30/23 10:14 AM        99            MD      Aidan
#
#    Last Name         Full Name       Waiting Time
# 94      Kerr       Samson Kerr  10 days, 23 hours
# 95   Doherty  Ibraheem Doherty   5 days, 19 hours
# 96    Garcia   Cordelia Garcia    3 days, 1 hours
# 97   Freeman    Oliwia Freeman   1 days, 21 hours
# 98  Friedman    Aidan Friedman   1 days, 21 hours

# %%
data['Waiting Time'].value_counts().head()
# Out:
# Waiting Time
# 2 days, 0 hours      3
# 25 days, 0 hours     2
# 31 days, 20 hours    2
# 3 days, 1 hours      2
# 7 days, 22 hours     2
# Name: count, dtype: int64

# %%
num = int(input("Enter number:"))
if num > 1:
    for i in range(2,(num//2) + 1):
        if (num%2) == 0:
            print(num,"is not prime number")
            break
    else:
        print(num,"is a prime number")
else:
    print(num,"is not a prime number")

# %%
n = int(input("Enter number: "))
fact = 1
for i in range(1, (n + 1)):
    fact *= i

print("Factorial number is :",fact)

# %%
#fibonacci number
n = int(input("Enter number of terms:"))
a,b = 0,1
count = 0
print("Fibonacci series: ")
while count < n:
    print(a, end=" ")
    a,b = b, a+b
    count += 1

# %%
s = input("Enter the string: ")
result = s[::-1]
print("Reversed the string:",result)

# %%
s = input("Enter the string: ")
if s == s[::-1]:
    print(s,"is a palindrome")
else:
    print(s,"is not a palindrome")

# %%
lst = input("Enter the numbers:")
lst1 = [int(x) for x in lst.split(",")]
result = max(lst1)
print("The largest element in a list:",result)

# %%
lst = input("Enter the numbers:")
lst1 = [int(x) for x in lst.split(",")]
result = max(lst1)
lst1.remove(result)
result1 = max(lst1)
print("The second largest element is:",result1)

# %%
a = int(input("Enter the numbers:"))
b = int(input("Enter the numbers: "))
a,b = b,a
print("After swapping of a is :",a)
print("After swapping of b is :",b)

# %%
a = int(input("Enter the numbers:"))
b = int(input("Enter the numbers: "))
temp = a
a = b
b = temp
print("After swapping of a is :",a)
print("After swapping of b is :",b)

# %%
n = int(input("Enter the number:"))
if n%2 == 0:
    print(n, "is even number")
else:
    print(n, "is odd number")

# %%
for i in range(1,10):
    if i%2 == 0:
        print(i)

# %%
n= int(input("Enter the numbers:"))
temp = n
sum_of_digits = 0

while temp > 0:
    digit = temp % 10
    sum_of_digits += digit ** len(str(n))
    temp //= 10
if n == sum_of_digits:
    print(n,"is an armstrong number")
else:
    print(n,"is not a armstrong number")

# %%
lst = input("Enter numbers seperated by commas:")
lst1 = [int(x) for x in lst.split(",")]
word = input("Enter numbers seperated by commas:")
word1 = [int(x) for x in word.split(",")]

result = list(set(lst1)&set(word1))

print("The common elements between two lists are:",result)

# %%
lst = input("Enter numbers seperated by commas:")
lst1 = [int(x) for x in lst.split(",")]

result = set(lst1)

print("After removing the duplicates:",result)

# %%
deva = input("Enter the string:")
vowels = 0
consonants = 0

for i in deva:
    if i in 'aeiouAEIOU':
        vowels += 1
    else:
        consonants += 1

print("The number of vowels in a string:",vowels)
print("The number of consonants in a strings:",consonants)

# %%
original_string = input("Enter the string:")
copied_string = original_string

print("Original string is:",original_string)
print("Copied string is:",copied_string)

# %%
num = input("Enter the numbers:")
num1 = [int(x) for x in num.split(",")]
deva = list(map(lambda x:x**2,num1))
print("The squaring of a number:",deva)

# %%
from collections import Counter

my_list = input("Enter numbers:")
my_list1 = [int(x) for x in my_list.split(",")]

frequency = Counter(my_list1)

print("The number of occurance in a string is:",frequency)

# %%
n = int(input("Enter number:"))
fact = 1

for i in range(1, n + 1):
    fact *= i
print("The factorial is:",fact)

# %%
n = int(input("Entre number:"))
a,b = 0,1
count = 0

print("Fibonacci series:")
while count < n:
    print(a, end=" ")
    a,b = b,a+b
    count +=1
